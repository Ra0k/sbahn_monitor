# %% [markdown]
# # Tracking One Train
#
# The challenge here is that we need to be able to track sbahns along the path they follow using only information about when they are planning on departing the next station. There is no unique id for each train trip, instead we have to:
# - identify the trip by the first station it starts at
# - match the next stop based on the route and planned departure

# %% [markdown]
# ### Questions about the Data Model
#
# - lines have start and end, but that isn't always the same as destination
#
# #### Lines
#
# This data in general we created by hand by david, so there may be some bugs or idiosyncracies in the data
#
# line:
#
#  - name of the line and some variation
#  - only provides distinction for the physical forks in the track, not including the variatons sbahns have
#
# station_id
#
#  - a station id, however these aren't unique to a line
#
# start & end
#
#  - these should represent something like the start and end of the lines. I guess this can help make the distinction between the variations to
#
# order
#  - the order of the line
#
# #### Stations
#
# station_id:
#
#  - the station id this is unique in the table
#
# station_name:
#
#  - normal name of station unique in table
#
#
# #### Departures
#
# station
#
# - station id from which the sbahn will depart
#
# departure_id
#
# - departure id is a unique id for the departure event, should be unique globally
#
# departure_time
#
# - datetime for planned departure
#
# product
#
# - which sbahn line, however the variation is not defined
#
# destination
#
# - normal name of destination, this can be different than the end of line
#
# delay
#
# - amount of delay if present
#
# passed_before
# platform
# canceled
# created_at
# updated_at

# %% [markdown]
# ## Imports

# %%
import os
from uuid import uuid4
# settings.py
from dotenv import load_dotenv
load_dotenv()

from joblib import Parallel, delayed
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine

# %% [markdown]
# ## DB Connection

# %%
engine = create_engine('postgresql://{username}:{password}@167.99.243.10/sbahn'.format(username=os.getenv('POSTGRE_USERNAME'), password=os.getenv('POSTGRE_PASSWORD')))

# %% [markdown]
# ## Getting Data
#
# ### Getting Departures
#
# Here we just want to grab the most crucial information to match the departures to the lines we have stored in a csv from the other notebook.

# %%
all_departures = """
select d.departure_id, d.destination, SUBSTRING(d.product, 7,2) as line, s.station_name, d.departure_time
from departures as d, stations as s
where d.station = s.station_id
;
"""

# %%
all_departures_df = pd.read_sql(all_departures, engine)

# %%
all_departures_df.head()
# Out:
#                                         departure_id  destination line  \
# 0  0a9a2eccec55ba56a824c854d9446898#1607516520000...   Ostbahnhof   S2
# 1  709cc878053eab9ed345e160412af2f3#1607516760000...  Altomünster   S2
# 2  3a710caa287a038c447034006c73a0d2#1607530920000...   Ostbahnhof   S2
# 3  c0325e8e6c3a69ca43aefd70a0e314bf#1607522640000...       Erding   S2
# 4  9101e990ed073aaf99a4f3105e7ccc63#1607543520000...       Erding   S2
#
#   station_name      departure_time
# 0  Altomünster 2020-12-09 12:22:00
# 1      Arnbach 2020-12-09 12:26:00
# 2  Altomünster 2020-12-09 16:22:00
# 3      Arnbach 2020-12-09 14:04:00
# 4  Altomünster 2020-12-09 19:52:00

# %%
all_departures_df.shape
# Out:
# (229901, 5)

# %% [markdown]
# ### Loading Additional Data
#
# This data originates from the other notebook and makes it easier to calculate the next stop.

# %%
line_data = pd.read_csv('line_data.csv')

# %%
line_data.head()
# Out:
#   line  line_id              start         end                    from  \
# 0   S8        1  Flughafen München  Herrsching       Flughafen München
# 1   S8        1  Flughafen München  Herrsching  Flughafen Besucherpark
# 2   S8        1  Flughafen München  Herrsching            Hallbergmoos
# 3   S8        1  Flughafen München  Herrsching                Ismaning
# 4   S8        1  Flughafen München  Herrsching            Unterföhring
#
#                        to  order  delta
# 0  Flughafen Besucherpark      1    2.0
# 1            Hallbergmoos      2    5.0
# 2                Ismaning      3    7.0
# 3            Unterföhring      4    4.0
# 4         Johanneskirchen      5    4.0

# %% [markdown]
# ### Merging Data

# %%
all_stops_df = pd.merge(all_departures_df, 
                        line_data,
                        left_on=['line','destination', 'station_name'], 
                        right_on=['line','end', 'from'], 
                        how='left'
                       )

# %%
all_stops_df
# Out:
#                                              departure_id  destination line  \
# 0       0a9a2eccec55ba56a824c854d9446898#1607516520000...   Ostbahnhof   S2
# 1       709cc878053eab9ed345e160412af2f3#1607516760000...  Altomünster   S2
# 2       3a710caa287a038c447034006c73a0d2#1607530920000...   Ostbahnhof   S2
# 3       c0325e8e6c3a69ca43aefd70a0e314bf#1607522640000...       Erding   S2
# 4       9101e990ed073aaf99a4f3105e7ccc63#1607543520000...       Erding   S2
# ...                                                   ...          ...  ...
# 248975  ca87e0bbcc759ad51b77332a9004a9a7#1608235080000...  Kreuzstraße   S7
# 248976  62874fbb170cab5f60b64e1e3fb37730#1608268140000...      Tutzing   S6
# 248977  482d1b0f7295af6494cdf276bb7f3ce1#1608235380000...  Altomünster   S2
# 248978  7ac4aea2349e825aef20bf7bdbe3c822#1608236040000...        Aying   S7
# 248979  b915e455d36834778991a4460f599ff6#1608236640000...    Ebersberg   S6
#
#               station_name      departure_time  line_id           start  \
# 0              Altomünster 2020-12-09 12:22:00      NaN             NaN
# 1                  Arnbach 2020-12-09 12:26:00     10.0          Erding
# 2              Altomünster 2020-12-09 16:22:00      NaN             NaN
# 3                  Arnbach 2020-12-09 14:04:00    110.0     Altomünster
# 4              Altomünster 2020-12-09 19:52:00    110.0     Altomünster
# ...                    ...                 ...      ...             ...
# 248975  Ostbahnhof München 2020-12-17 19:58:00    102.0  Wolfratshausen
# 248976         Possenhofen 2020-12-18 05:09:00      9.0       Ebersberg
# 248977   Rosenheimer Platz 2020-12-17 20:03:00     10.0          Erding
# 248978   Rosenheimer Platz 2020-12-17 20:14:00      NaN             NaN
# 248979           Trudering 2020-12-17 20:24:00    109.0         Tutzing
#
#                 end                from                to  order  delta
# 0               NaN                 NaN               NaN    NaN    NaN
# 1       Altomünster             Arnbach            Erdweg   34.0    4.0
# 2               NaN                 NaN               NaN    NaN    NaN
# 3            Erding             Arnbach  Markt Indersdorf    4.0    4.0
# 4            Erding         Altomünster    Kleinberghofen    1.0    5.0
# ...             ...                 ...               ...    ...    ...
# 248975  Kreuzstraße  Ostbahnhof München   St.-Martin-Str.   22.0    2.0
# 248976      Tutzing         Possenhofen         Feldafing   33.0    3.0
# 248977  Altomünster   Rosenheimer Platz           Isartor   15.0    2.0
# 248978          NaN                 NaN               NaN    NaN    NaN
# 248979    Ebersberg           Trudering         Gronsdorf   25.0    3.0
#
# [248980 rows x 12 columns]

# %% [markdown]
# ## Creating Train Trips

# %% [markdown]
# ### Create Unique IDs
#
# For each trip that starts at stop 0, this is obviously a unique train. Start from this point we'll try and work forward iteratively to detect the next train.

# %%
all_stops_df['train_id'] = all_stops_df.apply(lambda x: uuid4() if x.order == 1 else None, axis=1)

# %%
all_stops_df.train_id.isnull().sum()
# Out:
# 243432

# %% [markdown]
# ### Implementing Logic To Find Next Stop

# %%
def find_next_stop(data, current_index, timestamp, time_delta):
    candidates = data.copy()
    candidates = candidates[candidates.order.eq(current_index + 1)]
    candidates = candidates[candidates.departure_time.gt(timestamp)]
    candidates = candidates[candidates.train_id.isnull()]
    candidates['time_delta'] = candidates.departure_time - timestamp
    candidates = candidates.sort_values(by='time_delta')
    rows, cols = candidates.shape
    min_time_delta = candidates.time_delta.min()
    if rows == 0:
        return 1, 0, None
    elif min_time_delta > pd.Timedelta(max(5,time_delta*1.5), unit='minutes'):
        return 0, 1, None
    else:
        return 0, 0, candidates.iloc[0]['departure_id']

# %% [markdown]
# Now we just need to loop through each index of the stops in order and try and find the corresponding next stop.

# %%
line_ids = all_stops_df.line_id.dropna().unique().tolist()

# %%
lines_destinations = all_stops_df[['line', 'destination']]
unique_lines_destionations = lines_destinations.drop_duplicates()

# %% [markdown]
# ### Parallel Processing

# %%
def process_line(df):
    stop_indices = df.order.unique()
    stop_indices.sort()
    # We skip the last station since it's missing from the departures anyways
    for stop in stop_indices[0:len(stop_indices)-1]:
        id_not_null = ~df.train_id.isnull()
        current_stops = df[id_not_null & df.order.eq(stop)]
        next_stops = df[df.order.eq(stop+1)]

        total_no_rows = 0
        total_too_big = 0
        total_stops_considered = current_stops.shape[0]
        
        for index, row in current_stops.iterrows():
            no_rows, too_big, next_stops_departure_id = find_next_stop(next_stops, stop, row.departure_time, row.delta)
            total_no_rows += no_rows
            total_too_big += too_big
            if next_stops_departure_id is not None:
                df.loc[df.departure_id.eq(next_stops_departure_id), 'train_id'] = row.train_id
    return df

# %%
with Parallel(n_jobs=2) as parallel:
    accumulator = []
    n_iter = 0
    while len(accumulator) <= 2:
        results = parallel(delayed(process_line)(all_stops_df.copy()[all_stops_df.line_id.eq(line_id)]) for i in line_ids[0:3])
        accumulator += results # synchronization barrier
        n_iter += 1

# %% [markdown]
# ### Single Processing Alternative

# %%
# %%time
# We want to loop over each line and their stops in the correct order and then just 
# assume the nearest candidate in time and physical stop is the right match
for line_id in line_ids:
    print(line_id)
    correct_line = all_stops_df.line_id.eq(line_id)
    stop_indices = all_stops_df[correct_line].order.unique()
    stop_indices.sort()
    # We skip the last station since it's missing from the departures anyways
    for stop in stop_indices[0:len(stop_indices)-1]:
        print(stop)
        id_not_null = ~all_stops_df.train_id.isnull()
        current_stops = all_stops_df[id_not_null & correct_line & all_stops_df.order.eq(stop)]
        next_stops = all_stops_df[correct_line & all_stops_df.order.eq(stop+1)]

        total_no_rows = 0
        total_too_big = 0
        total_stops_considered = current_stops.shape[0]
        
        for index, row in current_stops.iterrows():
            no_rows, too_big, next_stops_departure_id = find_next_stop(next_stops, stop, row.departure_time, row.delta)
            total_no_rows += no_rows
            total_too_big += too_big
            if next_stops_departure_id is not None:
                all_stops_df.loc[all_stops_df.departure_id.eq(next_stops_departure_id), 'train_id'] = row.train_id
        print('Stops: {} Total with no rows: {}, total with time_delta too big: {}'.format(total_stops_considered,total_no_rows, total_too_big))
# Out:
# 10.0
# 1.0
# Stops: 122 Total with no rows: 0, total with time_delta too big: 0
# 2.0
# Stops: 122 Total with no rows: 0, total with time_delta too big: 0
# 3.0
# Stops: 122 Total with no rows: 0, total with time_delta too big: 0
# 4.0
# Stops: 122 Total with no rows: 0, total with time_delta too big: 0
# 5.0
# Stops: 122 Total with no rows: 0, total with time_delta too big: 3
# 6.0
# Stops: 119 Total with no rows: 0, total with time_delta too big: 6
# 7.0
# Stops: 113 Total with no rows: 0, total with time_delta too big: 0
# 8.0
# Stops: 113 Total with no rows: 0, total with time_delta too big: 0
# 9.0
# Stops: 113 Total with no rows: 2, total with time_delta too big: 0
# 10.0
# Stops: 111 Total with no rows: 0, total with time_delta too big: 0
# 11.0
# Stops: 111 Total with no rows: 1, total with time_delta too big: 0
# 12.0
# Stops: 110 Total with no rows: 0, total with time_delta too big: 0
# 13.0
# Stops: 110 Total with no rows: 1, total with time_delta too big: 109
# 14.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 15.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 16.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 17.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 18.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 19.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 20.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 21.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 22.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 23.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 24.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 25.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 26.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 27.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 29.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 30.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 31.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 32.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 33.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 34.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 35.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 110.0
# 1.0
# Stops: 116 Total with no rows: 3, total with time_delta too big: 0
# 2.0
# Stops: 113 Total with no rows: 1, total with time_delta too big: 0
# 3.0
# Stops: 112 Total with no rows: 0, total with time_delta too big: 0
# 4.0
# Stops: 112 Total with no rows: 0, total with time_delta too big: 0
# 5.0
# Stops: 112 Total with no rows: 0, total with time_delta too big: 0
# 6.0
# Stops: 112 Total with no rows: 0, total with time_delta too big: 0
# 7.0
# Stops: 112 Total with no rows: 0, total with time_delta too big: 0
# 8.0
# Stops: 112 Total with no rows: 0, total with time_delta too big: 0
# 9.0
# Stops: 112 Total with no rows: 112, total with time_delta too big: 0
# 11.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 12.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 13.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 14.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 15.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 16.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 17.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 18.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 19.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 20.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 21.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 22.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 23.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 24.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 25.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 26.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 27.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 28.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 29.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 30.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 31.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 32.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 33.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 34.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 35.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 9.0
# 1.0
# Stops: 262 Total with no rows: 4, total with time_delta too big: 0
# 2.0
# Stops: 258 Total with no rows: 1, total with time_delta too big: 257
# 3.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 4.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 5.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 6.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 7.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 8.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 9.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 10.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 11.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 12.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 13.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 14.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 15.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 16.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 17.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 18.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 19.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 20.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 21.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 22.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 23.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 24.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 25.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 26.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 27.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 28.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 29.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 30.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 31.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 32.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 33.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 108.0
# 1.0
# Stops: 398 Total with no rows: 1, total with time_delta too big: 397
# 2.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 3.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 4.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 5.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 6.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 7.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 8.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 9.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 10.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 11.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 12.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 13.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 14.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 15.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 16.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 17.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 18.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 19.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 1.0
# 1.0
# Stops: 430 Total with no rows: 10, total with time_delta too big: 0
# 2.0
# Stops: 420 Total with no rows: 0, total with time_delta too big: 0
# 3.0
# Stops: 420 Total with no rows: 0, total with time_delta too big: 0
# 4.0
# Stops: 420 Total with no rows: 0, total with time_delta too big: 0
# 5.0
# Stops: 420 Total with no rows: 1, total with time_delta too big: 0
# 6.0
# Stops: 419 Total with no rows: 0, total with time_delta too big: 0
# 7.0
# Stops: 419 Total with no rows: 0, total with time_delta too big: 0
# 8.0
# Stops: 419 Total with no rows: 1, total with time_delta too big: 0
# 9.0
# Stops: 418 Total with no rows: 1, total with time_delta too big: 417
# 10.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 11.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 12.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 13.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 14.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 15.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 16.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 17.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 18.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 19.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 20.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 21.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 22.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 23.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 24.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 25.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 26.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 27.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 28.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 29.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 30.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 101.0
# 1.0
# Stops: 424 Total with no rows: 7, total with time_delta too big: 0
# 2.0
# Stops: 417 Total with no rows: 0, total with time_delta too big: 0
# 3.0
# Stops: 417 Total with no rows: 0, total with time_delta too big: 0
# 4.0
# Stops: 417 Total with no rows: 0, total with time_delta too big: 0
# 5.0
# Stops: 417 Total with no rows: 4, total with time_delta too big: 0
# 6.0
# Stops: 413 Total with no rows: 0, total with time_delta too big: 0
# 7.0
# Stops: 413 Total with no rows: 3, total with time_delta too big: 0
# 8.0
# Stops: 410 Total with no rows: 0, total with time_delta too big: 0
# 9.0
# Stops: 410 Total with no rows: 0, total with time_delta too big: 0
# 10.0
# Stops: 410 Total with no rows: 0, total with time_delta too big: 0
# 11.0
# Stops: 410 Total with no rows: 1, total with time_delta too big: 0
# 12.0
# Stops: 409 Total with no rows: 1, total with time_delta too big: 0
# 13.0
# Stops: 408 Total with no rows: 0, total with time_delta too big: 0
# 14.0
# Stops: 408 Total with no rows: 0, total with time_delta too big: 0
# 15.0
# Stops: 408 Total with no rows: 1, total with time_delta too big: 0
# 16.0
# Stops: 407 Total with no rows: 0, total with time_delta too big: 0
# 17.0
# Stops: 407 Total with no rows: 0, total with time_delta too big: 0
# 18.0
# Stops: 407 Total with no rows: 0, total with time_delta too big: 0
# 19.0
# Stops: 407 Total with no rows: 0, total with time_delta too big: 0
# 20.0
# Stops: 407 Total with no rows: 0, total with time_delta too big: 0
# 21.0
# Stops: 407 Total with no rows: 0, total with time_delta too big: 0
# 22.0
# Stops: 407 Total with no rows: 1, total with time_delta too big: 0
# 23.0
# Stops: 406 Total with no rows: 0, total with time_delta too big: 0
# 24.0
# Stops: 406 Total with no rows: 0, total with time_delta too big: 0
# 25.0
# Stops: 406 Total with no rows: 0, total with time_delta too big: 0
# 26.0
# Stops: 406 Total with no rows: 0, total with time_delta too big: 0
# 27.0
# Stops: 406 Total with no rows: 0, total with time_delta too big: 0
# 28.0
# Stops: 406 Total with no rows: 0, total with time_delta too big: 0
# 29.0
# Stops: 406 Total with no rows: 0, total with time_delta too big: 0
# 30.0
# Stops: 406 Total with no rows: 0, total with time_delta too big: 0
# 103.0
# 1.0
# Stops: 294 Total with no rows: 1, total with time_delta too big: 169
# 2.0
# Stops: 124 Total with no rows: 0, total with time_delta too big: 0
# 3.0
# Stops: 124 Total with no rows: 0, total with time_delta too big: 124
# 4.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 5.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 6.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 7.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 8.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 9.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 10.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 11.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 12.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 13.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 14.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 15.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 16.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 17.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 18.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 19.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 20.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 21.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 22.0
# Stops: 0 Total with no rows: 0, total with time_delta too big: 0
# 5.0
# 1.0
# Stops: 322 Total with no rows: 0, total with time_delta too big: 0
# 2.0
# Stops: 322 Total with no rows: 0, total with time_delta too big: 0
# 3.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/anaconda3/envs/sbahn/lib/python3.8/site-packages/pandas/core/ops/__init__.py in flex_wrapper(self, other, level, fill_value, axis)
#     421                 self = self.fillna(fill_value)
#     422
# --> 423             return op(self, other)
#     424
#     425     flex_wrapper.__name__ = name
#
# ~/anaconda3/envs/sbahn/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~/anaconda3/envs/sbahn/lib/python3.8/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     368         rvalues = extract_array(other, extract_numpy=True)
#     369
# --> 370         res_values = comparison_op(lvalues, rvalues, op)
#     371
#     372         return self._construct_result(res_values, name=res_name)
#
# ~/anaconda3/envs/sbahn/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     242
#     243     elif is_object_dtype(lvalues.dtype):
# --> 244         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     245
#     246     else:
#
# ~/anaconda3/envs/sbahn/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      54         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      55     else:
# ---> 56         result = libops.scalar_compare(x.ravel(), y, op)
#      57     return result.reshape(x.shape)
#      58
#
# KeyboardInterrupt:
